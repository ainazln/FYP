# %%
# %%capture --no-stderr --no-stdout --no-display output
# Data manipulation/analysis
import numpy as np
import pandas as pd

# Text preprocessing/analysis
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob
from scipy.sparse import hstack, csr_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="whitegrid", context='talk')

# %%
# read data
df = pd.read_csv("newdataclean.csv", index_col='time',parse_dates=True)

newdf = df[df['newReview'].notna()]
newdf.head(10)
# Out:
#                      Unnamed: 0  \
# time
# 2020-12-17 23:03:00           0
# 2020-10-15 21:01:00           1
# 2020-10-14 00:26:00           2
# 2020-10-08 17:31:00           3
# 2020-10-01 17:00:00           4
# 2020-09-12 22:54:00           5
# 2020-09-11 19:08:00           6
# 2020-09-07 13:36:00           7
# 2020-09-07 01:57:00           8
# 2020-08-26 21:24:00          10
#
#                                                                  title  \
# time
# 2020-12-17 23:03:00               VOIR Drawstring Bag VN201460-C082003
# 2020-10-15 21:01:00                VOIR Crossbody Bag VN201435-C032001
# 2020-10-14 00:26:00  VOIR Mid-Sized Sling Bag with Zip Closure VN20...
# 2020-10-08 17:31:00  [SHOPEE EXCLUSIVE] VOIR Quilted Sling Bag with...
# 2020-10-01 17:00:00        VOIR Quilted Crossbody Bag VN201428-C031912
# 2020-09-12 22:54:00  SODA Women's Basic Puff Sleeve Dress SYC00842-...
# 2020-09-11 19:08:00          VOIR Mini Top Handle Bag VN201431-C031912
# ...

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\AINA
# [nltk_data]     ZULIANA\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sid = SentimentIntensityAnalyzer()
newdf[['neg', 'neu', 'pos', 'polarity']] = newdf['newReview'].apply(sid.polarity_scores).apply(pd.Series)
newdf.head(50)
# Out:
# C:\Users\AINA ZULIANA\anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                      Unnamed: 0  \
# time
# 2020-12-17 23:03:00           0
# 2020-10-15 21:01:00           1
# 2020-10-14 00:26:00           2
# 2020-10-08 17:31:00           3
# 2020-10-01 17:00:00           4
# 2020-09-12 22:54:00           5
# 2020-09-11 19:08:00           6
# 2020-09-07 13:36:00           7
# 2020-09-07 01:57:00           8
# 2020-08-26 21:24:00          10
# 2020-08-24 21:07:00          11
# 2020-08-24 21:07:00          12
# 2020-08-16 19:00:00          15
# 2020-08-13 21:47:00          16
# 2020-08-08 16:34:00          19
# 2020-08-07 16:04:00          20
# ...

# %%
def sentiment(row):
   if row['polarity'] == 0:
      return 'Neutral'
   if row['polarity'] > 0:
      return 'Positive'
   if row['polarity'] < 0:
      return 'Negative'

newdf['sentiment'] = newdf.apply(lambda row: sentiment(row), axis=1)
newdf.head(50)
# Out:
# <ipython-input-5-d754f34ae2bd>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['sentiment'] = newdf.apply(lambda row: sentiment(row), axis=1)
#                      Unnamed: 0  \
# time
# 2020-12-17 23:03:00           0
# 2020-10-15 21:01:00           1
# 2020-10-14 00:26:00           2
# 2020-10-08 17:31:00           3
# 2020-10-01 17:00:00           4
# 2020-09-12 22:54:00           5
# 2020-09-11 19:08:00           6
# 2020-09-07 13:36:00           7
# 2020-09-07 01:57:00           8
# 2020-08-26 21:24:00          10
# 2020-08-24 21:07:00          11
# 2020-08-24 21:07:00          12
# 2020-08-16 19:00:00          15
# 2020-08-13 21:47:00          16
# 2020-08-08 16:34:00          19
# 2020-08-07 16:04:00          20
# ...

# %%
newdf['Week']=newdf.index.week
newdf['Month']=newdf.index.month
newdf['Year']=newdf.index.year

newdf.head(30)
# Out:
# <ipython-input-6-33da4b33bd73>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Week']=newdf.index.week
# <ipython-input-6-33da4b33bd73>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Month']=newdf.index.month
# <ipython-input-6-33da4b33bd73>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# dropping passed columns 
newdf.drop(["Unnamed: 0", "review", "user", "neg", "neu", "pos", "polarity", "Month", "Year"], axis = 1, inplace = True) 
newdf.head()
# Out:
# C:\Users\AINA ZULIANA\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                                  title  \
# time
# 2020-12-17 23:03:00               VOIR Drawstring Bag VN201460-C082003
# 2020-10-15 21:01:00                VOIR Crossbody Bag VN201435-C032001
# 2020-10-14 00:26:00  VOIR Mid-Sized Sling Bag with Zip Closure VN20...
# 2020-10-08 17:31:00  [SHOPEE EXCLUSIVE] VOIR Quilted Sling Bag with...
# 2020-10-01 17:00:00        VOIR Quilted Crossbody Bag VN201428-C031912
#
#                      rating  \
# time
# 2020-12-17 23:03:00     1.0
# 2020-10-15 21:01:00     1.0
# 2020-10-14 00:26:00     1.0
# 2020-10-08 17:31:00     1.0
# 2020-10-01 17:00:00     1.0
#
# ...

# %%
# dropping passed columns 
newdf.drop(["rating"], axis = 1, inplace = True) 
newdf.head()
# Out:
# C:\Users\AINA ZULIANA\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                                                                  title  \
# time
# 2020-12-17 23:03:00               VOIR Drawstring Bag VN201460-C082003
# 2020-10-15 21:01:00                VOIR Crossbody Bag VN201435-C032001
# 2020-10-14 00:26:00  VOIR Mid-Sized Sling Bag with Zip Closure VN20...
# 2020-10-08 17:31:00  [SHOPEE EXCLUSIVE] VOIR Quilted Sling Bag with...
# 2020-10-01 17:00:00        VOIR Quilted Crossbody Bag VN201428-C031912
#
#                                                              newReview  \
# time
# 2020-12-17 23:03:00  not satisfy bag seems like show bag scalp ady ...
# ...

# %%
#rename column
newdf.rename(columns = {'time':'Time',  'title':'Title', 'newReview':'Review', 'sentiment':'Sentiment'}, inplace = True)
newdf.head(60)
# Out:
# C:\Users\AINA ZULIANA\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                                                                  Title  \
# time
# 2020-12-17 23:03:00               VOIR Drawstring Bag VN201460-C082003
# 2020-10-15 21:01:00                VOIR Crossbody Bag VN201435-C032001
# 2020-10-14 00:26:00  VOIR Mid-Sized Sling Bag with Zip Closure VN20...
# 2020-10-08 17:31:00  [SHOPEE EXCLUSIVE] VOIR Quilted Sling Bag with...
# 2020-10-01 17:00:00        VOIR Quilted Crossbody Bag VN201428-C031912
# 2020-09-12 22:54:00  SODA Women's Basic Puff Sleeve Dress SYC00842-...
# 2020-09-11 19:08:00          VOIR Mini Top Handle Bag VN201431-C031912
# ...

# %%
newdf.to_csv("listweek.csv")
